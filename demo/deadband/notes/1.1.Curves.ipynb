# %% [markdown]
# # Curves

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

import scienceplots

# %%
# %matplotlib inline

# %%
load = pd.read_excel("./../cases/DataLoad.xlsx")
pv = pd.read_excel("./../cases/DataPV.xlsx")
wind = pd.read_excel("./../cases/DataWind.xlsx")

# %%
curve = pd.DataFrame()
curve["Time"] = pd.date_range(start="2024-02-01 00:00:00",
                              end="2024-02-01 23:59:00",
                              freq="min").time
curve["Load"] = load["Total_Power"].values[:1440]
curve["PV"] = pv["Power"].values[:1440]
curve["Wind"] = wind["Power"].values[:1440]
# Smooth the curves
for col in ["Load", "PV", "Wind"]:
    curve[col] = curve[col].rolling(window=25, center=True, min_periods=1).mean()

curve[["Load", "PV", "Wind"]] = curve[["Load", "PV", "Wind"]] / \
    curve[["Load", "PV", "Wind"]].max()

# %%
plt.style.use(['default', 'ieee'])

ax = curve.plot(x='Time', y=['PV', 'Wind', 'Load'],
                color=['tab:orange', 'tab:blue', 'tab:gray'],
                style=['-', '-', '-'],
                linewidth=1,
                figsize=(10, 4),)
_ = ax.legend(labels=['PV', 'Wind', 'Load'])
_ = ax.grid()
_ = ax.set_xlabel("Time [Min.]")
_ = ax.set_ylabel("Scaled Power")
_ = ax.set_xlim([curve["Time"].min(), curve["Time"].max()])

# %%
x_old = np.linspace(0, 1439, 1440)
x_new = np.linspace(0, 1439, 1440*60)

curve_interp = pd.DataFrame()
curve_interp["Time"] = range(0, 1440*60)  # second
np.random.seed(42)
for col in ["Load", "PV", "Wind"]:
    y_new = np.interp(x_new, x_old, curve[col].values)
    y_error = np.random.normal(loc=0, scale=0.001, size=len(y_new)) # random error
    curve_interp[col] = y_new + y_error

# %%
ax = curve_interp.plot(x='Time', y=['PV', 'Wind', 'Load'],
                       color=['tab:orange', 'tab:blue', 'tab:gray'],
                       style=['-', '-', '-'],
                       linewidth=1,
                       figsize=(10, 4),)
_ = ax.legend(labels=['PV', 'Wind', 'Load'])
_ = ax.grid()
_ = ax.set_xlabel("Time [Second]")
_ = ax.set_ylabel("Scaled Power")
_ = ax.set_xlim([curve_interp["Time"].min(), curve_interp["Time"].max()])

# %%
curve.to_csv("./../cases/Curve.csv", index=False)
curve_interp.to_csv("./../cases/CurveInterp.csv", index=False)
